# %% [markdown]
# # 11/14/2018
#
# RNAseq
#
# Brian Haas
#
# Genome guided and genome free assembly

# %% [markdown]
# https://rrwick.github.io/Bandage/
#
# https://github.com/trinityrnaseq/CSHLadvSeqTech/wiki/Home/229b766e058e6798fb87024cfb1c0d9e4fb77114

# %% [markdown]
# ```
# [nathalia@aws] $  cd ~/workspace
# [nathalia@aws] $  pwd
# /home/ubuntu/workspace
#
# [nathalia@aws] $  mkdir transreco
# [nathalia@aws] $  cd transreco/
# [nathalia@aws] $  pwd
# /home/ubuntu/workspace/transreco
#
# [nathalia@aws] $  cp -r ~/workspace/data/trinity/rnaseq/* .
# [nathalia@aws] $  lhtr
# total 2.0M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
#
# ```

# %% [markdown]
# # IGV

# %% [markdown]
# ```
# [nathalia@aws] $  samtools faidx minigenome.fa
# [nathalia@aws] $  lhtr
# total 2.0M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# ```

# %% [markdown]
# http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/
#
# Get `.fa` and `.gtf` links
#
# Genome tab > Load from URL > Load `.fa`
#
# File tab > Load from URL > Load `.gtf`

# %% [markdown]
# ![igv1](igv1_minigenome.png)

# %% [markdown]
# # Genome-guided Transcript Reconstruction

# %% [markdown]
# ## Align with HISAT2

# %% [markdown]
# ```
# [nathalia@aws] $  hisat2_extract_splice_sites.py minigenome.gtf  > minigenome.gtf.ss
# [nathalia@aws] $  hisat2_extract_exons.py minigenome.gtf > minigenome.gtf.exons
# [nathalia@aws] $  hisat2-build --exon minigenome.gtf.exons \
# >        --ss minigenome.gtf.ss \
# >        -p 2 minigenome.fa minigenome.fa
# Settings:
#   Output files: "minigenome.fa.*.ht2"
#   Line rate: 7 (line is 128 bytes)
#   Lines per side: 1 (side is 128 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Local offset rate: 3 (one in 8)
#   Local fTable chars: 6
#   Local sequence length: 57344
#   Local sequence overlap between two consecutive indexes: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   minigenome.fa
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to read SNPs and splice sites: 00:00:00
# Generation 0 (713858 -> 713858 nodes, 0 ranks)
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# Generation 1 (714349 -> 714349 nodes, 0 ranks)
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# Generation 2 (715331 -> 715331 nodes, 0 ranks)
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# Generation 3 (717296 -> 717296 nodes, 0 ranks)
# BUILT FROM_INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# RESIZE NODES: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 92 361077
# 274 360163
# FINISHED RECURSIVE SORTS: 0
# SORT NODES: 0
# MERGE, UPDATE RANK: 0
# Generation 4 (721240 -> 716850 nodes, 708915 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 356645
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 5 (716893 -> 716881 nodes, 711511 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 1
# 175 360205
# 174 356676
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 1
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 1
# Generation 6 (716954 -> 716942 nodes, 712221 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 356737
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 7 (717076 -> 717006 nodes, 713114 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 356801
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 8 (717195 -> 717134 nodes, 714405 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 356929
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 9 (717451 -> 717390 nodes, 715920 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 357185
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 10 (717961 -> 717900 nodes, 717651 ranks)
# ALLOCATE FROM_TABLE: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 357695
# FINISHED RECURSIVE SORTS: 0
# BUILD TABLE: 0
# BUILD INDEX: 0
# COUNTED NEW NODES: 0
# COUNTED TEMP NODES: 0
# RESIZED NODES: 0
# RESIZED NODES: 0
# MADE NEW NODES: 0
# MERGEUPDATERANK: 0
# TOTAL TIME: 0
# Generation 11 (717952 -> 717899 nodes, 717899 ranks)
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 175 360205
# 174 357694
# FINISHED RECURSIVE SORTS: 0
# Generating edges...
# NODE.TO -> GENOME POS: 0
# BUILD FROM_INDEX 0
# COUNTED NEW EDGES: 0
# MADE NEW EDGES: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 165 103481
# 186 102910
# FINISHED RECURSIVE SORTS: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 163 77015
# 188 76207
# FINISHED RECURSIVE SORTS: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 166 76679
# 185 76245
# FINISHED RECURSIVE SORTS: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 204 103369
# 147 102482
# FINISHED RECURSIVE SORTS: 0
# SORTED NEW EDGES: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 176 360448
# 175 357451
# FINISHED RECURSIVE SORTS: 0
# RE-SORTED NODES: 0
# PROCESS EDGES: 0
# REMOVE Y: 0
# COUNT NUMBER IN EACH BIN: 0
# FINISHED FIRST ROUND: 0
# 176 360797
# 175 357592
# FINISHED RECURSIVE SORTS: 0
# SORT, Make index: 0
# TOTAL: 0
# Allocating ftab, absorbFtab
# Entering GFM loop
# Exited GFM loop
# fchr[A]: 0
# fchr[C]: 206391
# fchr[G]: 359613
# fchr[T]: 512537
# fchr[$]: 718388
# Exiting GFM::buildToDisk()
# Returning from initFromVector
# Wrote 4639748 bytes to primary GFM file: minigenome.fa.1.ht2
# Wrote 179480 bytes to secondary GFM file: minigenome.fa.2.ht2
# Re-opening _in1 and _in2 as input streams
# Returning from GFM constructor
# Returning from initFromVector
# Wrote 520257 bytes to primary GFM file: minigenome.fa.5.ht2
# Wrote 182410 bytes to secondary GFM file: minigenome.fa.6.ht2
# Re-opening _in5 and _in5 as input streams
# Returning from HierEbwt constructor
# Headers:
#     len: 713338
#     gbwtLen: 718389
#     nodes: 717898
#     sz: 356669
#     gbwtSz: 359195
#     lineRate: 7
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 0
#     eftabSz: 0
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 44869
#     offsSz: 179476
#     lineSz: 128
#     sideSz: 128
#     sideGbwtSz: 104
#     sideGbwtLen: 208
#     numSides: 3454
#     numLines: 3454
#     gbwtTotLen: 442112
#     gbwtTotSz: 442112
#     reverse: 0
#     linearFM: No
# Total time for call to driver() for forward index: 00:00:02
# [nathalia@aws] $  lhtr
# total 7.5M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >     -1 data/sA_rep1_1.fastq.gz -2 data/sA_rep1_2.fastq.gz \
# >     | samtools view -Sb -F 4 \
# >     | samtools sort  -o sA_rep1.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     827 (3.31%) aligned concordantly 0 times
#     24093 (96.37%) aligned concordantly exactly 1 time
#     80 (0.32%) aligned concordantly >1 times
#     ----
#     827 pairs aligned concordantly 0 times; of these:
#       2 (0.24%) aligned discordantly 1 time
#     ----
#     825 pairs aligned 0 times concordantly or discordantly; of these:
#       1650 mates make up the pairs; of these:
#         822 (49.82%) aligned 0 times
#         814 (49.33%) aligned exactly 1 time
#         14 (0.85%) aligned >1 times
# 98.36% overall alignment rate
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >       -1 data/sA_rep2_1.fastq.gz -2 data/sA_rep2_2.fastq.gz \
# >       | samtools view -Sb -F 4 \
# >       | samtools sort  -o sA_rep2.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     794 (3.18%) aligned concordantly 0 times
#     24143 (96.57%) aligned concordantly exactly 1 time
#     63 (0.25%) aligned concordantly >1 times
#     ----
#     794 pairs aligned concordantly 0 times; of these:
#       6 (0.76%) aligned discordantly 1 time
#     ----
#     788 pairs aligned 0 times concordantly or discordantly; of these:
#       1576 mates make up the pairs; of these:
#         787 (49.94%) aligned 0 times
#         782 (49.62%) aligned exactly 1 time
#         7 (0.44%) aligned >1 times
# 98.43% overall alignment rate
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >        -1 data/sA_rep3_1.fastq.gz -2 data/sA_rep3_2.fastq.gz \
# >        | samtools view -Sb -F 4 \
# >        | samtools sort  -o sA_rep3.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     791 (3.16%) aligned concordantly 0 times
#     24099 (96.40%) aligned concordantly exactly 1 time
#     110 (0.44%) aligned concordantly >1 times
#     ----
#     791 pairs aligned concordantly 0 times; of these:
#       2 (0.25%) aligned discordantly 1 time
#     ----
#     789 pairs aligned 0 times concordantly or discordantly; of these:
#       1578 mates make up the pairs; of these:
#         785 (49.75%) aligned 0 times
#         781 (49.49%) aligned exactly 1 time
#         12 (0.76%) aligned >1 times
# 98.43% overall alignment rate
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >        -1 data/sB_rep1_1.fastq.gz -2 data/sB_rep1_2.fastq.gz \
# >        | samtools view -Sb -F 4 \
# >        | samtools sort  -o sB_rep1.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     835 (3.34%) aligned concordantly 0 times
#     24071 (96.28%) aligned concordantly exactly 1 time
#     94 (0.38%) aligned concordantly >1 times
#     ----
#     835 pairs aligned concordantly 0 times; of these:
#       5 (0.60%) aligned discordantly 1 time
#     ----
#     830 pairs aligned 0 times concordantly or discordantly; of these:
#       1660 mates make up the pairs; of these:
#         828 (49.88%) aligned 0 times
#         828 (49.88%) aligned exactly 1 time
#         4 (0.24%) aligned >1 times
# 98.34% overall alignment rate
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >        -1 data/sB_rep2_1.fastq.gz -2 data/sB_rep2_2.fastq.gz \
# >        | samtools view -Sb -F 4 \
# >        | samtools sort  -o sB_rep2.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     736 (2.94%) aligned concordantly 0 times
#     24188 (96.75%) aligned concordantly exactly 1 time
#     76 (0.30%) aligned concordantly >1 times
#     ----
#     736 pairs aligned concordantly 0 times; of these:
#       3 (0.41%) aligned discordantly 1 time
#     ----
#     733 pairs aligned 0 times concordantly or discordantly; of these:
#       1466 mates make up the pairs; of these:
#         733 (50.00%) aligned 0 times
#         722 (49.25%) aligned exactly 1 time
#         11 (0.75%) aligned >1 times
# 98.53% overall alignment rate
# [nathalia@aws] $  hisat2 --dta -x minigenome.fa -p 2 \
# >        -1 data/sB_rep3_1.fastq.gz -2 data/sB_rep3_2.fastq.gz \
# >        | samtools view -Sb -F 4 \
# >        | samtools sort  -o sB_rep3.cSorted.hisat2.minigenome.fa.bam
# 25000 reads; of these:
#   25000 (100.00%) were paired; of these:
#     720 (2.88%) aligned concordantly 0 times
#     24203 (96.81%) aligned concordantly exactly 1 time
#     77 (0.31%) aligned concordantly >1 times
#     ----
#     720 pairs aligned concordantly 0 times; of these:
#       3 (0.42%) aligned discordantly 1 time
#     ----
#     717 pairs aligned 0 times concordantly or discordantly; of these:
#       1434 mates make up the pairs; of these:
#         717 (50.00%) aligned 0 times
#         710 (49.51%) aligned exactly 1 time
#         7 (0.49%) aligned >1 times
# 98.57% overall alignment rate
#
# ```

# %% [markdown]
# ## Index each of the bam files for IGV

# %% [markdown]
# ```
# [nathalia@aws] $  for file in *.bam
# >    do
# >    samtools index $file
# >    echo indexed $file
# >    done
# indexed sA_rep1.cSorted.hisat2.minigenome.fa.bam
# indexed sA_rep2.cSorted.hisat2.minigenome.fa.bam
# indexed sA_rep3.cSorted.hisat2.minigenome.fa.bam
# indexed sB_rep1.cSorted.hisat2.minigenome.fa.bam
# indexed sB_rep2.cSorted.hisat2.minigenome.fa.bam
# indexed sB_rep3.cSorted.hisat2.minigenome.fa.bam
# ```

# %% [markdown]
# http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/sA_rep1.cSorted.hisat2.minigenome.fa.bam
#
# http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/sB_rep1.cSorted.hisat2.minigenome.fa.bam

# %% [markdown]
# ![igv2](bam_igv.png)

# %% [markdown]
# ## Reconstruct transcripts using StringTie

# %% [markdown]
# ```
# [nathalia@aws] $  for file in *.bam
# >    do
# >    stringtie $file -o $file.stringtie.GTF
# >    echo done running stringtie on $file
# >    done
# done running stringtie on sA_rep1.cSorted.hisat2.minigenome.fa.bam
# done running stringtie on sA_rep2.cSorted.hisat2.minigenome.fa.bam
# done running stringtie on sA_rep3.cSorted.hisat2.minigenome.fa.bam
# done running stringtie on sB_rep1.cSorted.hisat2.minigenome.fa.bam
# done running stringtie on sB_rep2.cSorted.hisat2.minigenome.fa.bam
# done running stringtie on sB_rep3.cSorted.hisat2.minigenome.fa.bam
#
# [nathalia@aws] $  stringtie --merge -o stringtie.final.GTF  *.stringtie.GTF
#
# ```

# %% [markdown]
# http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/stringtie.final.GTF
#
# Load into IGV

# %% [markdown]
# ![stringtie](stringtie_final.png)

# %% [markdown]
# # Genome-free de novo transcript reconstruction with TRINITY

# %% [markdown]
# ```
# [nathalia@aws] $  export TRINITY_HOME=~/trinityrnaseq-Trinity-v2.5.1
#
# [nathalia@aws] $  $TRINITY_HOME/Trinity --samples_file samples.txt \
# >       --seqType fq --CPU 2 --max_memory 1G
#
#
#      ______  ____   ____  ____   ____  ______  __ __
#     |      ||    \ |    ||    \ |    ||      ||  |  |
#     |      ||  D  ) |  | |  _  | |  | |      ||  |  |
#     |_|  |_||    /  |  | |  |  | |  | |_|  |_||  ~  |
#       |  |  |    \  |  | |  |  | |  |   |  |  |___, |
#       |  |  |  .  \ |  | |  |  | |  |   |  |  |     |
#       |__|  |__|\_||____||__|__||____|  |__|  |____/
#
#
# Left read files: $VAR1 = [
#           'data/sA_rep1_1.fastq.gz',
#           'data/sA_rep2_1.fastq.gz',
#           'data/sA_rep3_1.fastq.gz',
#           'data/sB_rep1_1.fastq.gz',
#           'data/sB_rep2_1.fastq.gz',
#           'data/sB_rep3_1.fastq.gz'
#         ];
# Right read files: $VAR1 = [
#           'data/sA_rep1_2.fastq.gz',
#           'data/sA_rep2_2.fastq.gz',
#           'data/sA_rep3_2.fastq.gz',
#           'data/sB_rep1_2.fastq.gz',
#           'data/sB_rep2_2.fastq.gz',
#           'data/sB_rep3_2.fastq.gz'
#         ];
#
#
#
# ********************************************************************
# ** Warning, Trinity cannot determine which version of Java is being used.  Version 1.8 is required.
#
# Attempting to continue in 30 seconds
# ********************************************************************
#
#
# Trinity version: Trinity-v2.5.1
# -ERROR: couldn't run the network check to confirm latest Trinity software version.
#
# Wednesday, November 14, 2018: 15:51:22	CMD: java -Xmx64m -XX:ParallelGCThreads=2  -jar /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/ExitTester.jar 0
# Wednesday, November 14, 2018: 15:51:22	CMD: java -Xmx64m -XX:ParallelGCThreads=2  -jar /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/ExitTester.jar 1
# Wednesday, November 14, 2018: 15:51:22	CMD: mkdir -p /workspace/transreco/trinity_out_dir
# Wednesday, November 14, 2018: 15:51:22	CMD: mkdir -p /workspace/transreco/trinity_out_dir/chrysalis
#
#
# ----------------------------------------------------------------------------------
# -------------- Trinity Phase 1: Clustering of RNA-Seq Reads  ---------------------
# ----------------------------------------------------------------------------------
#
# ---------------------------------------------------------------
# ------------ In silico Read Normalization ---------------------
# -- (Removing Excess Reads Beyond 50 Coverage --
# ---------------------------------------------------------------
#
# # running normalization on reads: $VAR1 = [
#           [
#             '/workspace/transreco/data/sA_rep1_1.fastq.gz',
#             '/workspace/transreco/data/sA_rep2_1.fastq.gz',
#             '/workspace/transreco/data/sA_rep3_1.fastq.gz',
#             '/workspace/transreco/data/sB_rep1_1.fastq.gz',
#             '/workspace/transreco/data/sB_rep2_1.fastq.gz',
#             '/workspace/transreco/data/sB_rep3_1.fastq.gz'
#           ],
#           [
#             '/workspace/transreco/data/sA_rep1_2.fastq.gz',
#             '/workspace/transreco/data/sA_rep2_2.fastq.gz',
#             '/workspace/transreco/data/sA_rep3_2.fastq.gz',
#             '/workspace/transreco/data/sB_rep1_2.fastq.gz',
#             '/workspace/transreco/data/sB_rep2_2.fastq.gz',
#             '/workspace/transreco/data/sB_rep3_2.fastq.gz'
#           ]
#         ];
#
#
# Wednesday, November 14, 2018: 15:51:22	CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/insilico_read_normalization.pl --seqType fq --JM 1G  --max_cov 50 --CPU 2 --output /workspace/transreco/trinity_out_dir/insilico_read_normalization   --max_pct_stdev 10000  --left /workspace/transreco/data/sA_rep1_1.fastq.gz,/workspace/transreco/data/sA_rep2_1.fastq.gz,/workspace/transreco/data/sA_rep3_1.fastq.gz,/workspace/transreco/data/sB_rep1_1.fastq.gz,/workspace/transreco/data/sB_rep2_1.fastq.gz,/workspace/transreco/data/sB_rep3_1.fastq.gz --right /workspace/transreco/data/sA_rep1_2.fastq.gz,/workspace/transreco/data/sA_rep2_2.fastq.gz,/workspace/transreco/data/sA_rep3_2.fastq.gz,/workspace/transreco/data/sB_rep1_2.fastq.gz,/workspace/transreco/data/sB_rep2_2.fastq.gz,/workspace/transreco/data/sB_rep3_2.fastq.gz --pairs_together --PARALLEL_STATS
# Converting input files. (both directions in parallel)CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep1_1.fastq.gz) >> left.fa
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep1_2.fastq.gz) >> right.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep2_1.fastq.gz) >> left.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep2_2.fastq.gz) >> right.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep3_2.fastq.gz) >> right.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sA_rep3_1.fastq.gz) >> left.fa
# CMD finished (1 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep1_2.fastq.gz) >> right.fa
# CMD finished (1 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep1_1.fastq.gz) >> left.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep2_2.fastq.gz) >> right.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep2_1.fastq.gz) >> left.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep3_2.fastq.gz) >> right.fa
# CMD finished (0 seconds)
# CMD: seqtk-trinity seq -A <(gunzip -c /workspace/transreco/data/sB_rep3_1.fastq.gz) >> left.fa
# CMD finished (0 seconds)
# CMD finished (0 seconds)
# CMD: touch left.fa.ok
# CMD finished (0 seconds)
# CMD: touch right.fa.ok
# CMD finished (0 seconds)
# Done converting input files.CMD: cat left.fa right.fa > both.fa
# CMD finished (0 seconds)
# CMD: touch both.fa.ok
# CMD finished (0 seconds)
# -------------------------------------------
# ----------- Jellyfish  --------------------
# -- (building a k-mer catalog from reads) --
# -------------------------------------------
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//trinity-plugins/jellyfish/bin/jellyfish count -t 2 -m 25 -s 100000000  --canonical  both.fa
# CMD finished (3 seconds)
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//trinity-plugins/jellyfish/bin/jellyfish histo -t 2 -o jellyfish.K25.min2.kmers.fa.histo mer_counts.jf
# CMD finished (0 seconds)
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//trinity-plugins/jellyfish/bin/jellyfish dump -L 2 mer_counts.jf > jellyfish.K25.min2.kmers.fa
# CMD finished (0 seconds)
# CMD: touch jellyfish.K25.min2.kmers.fa.success
# CMD finished (0 seconds)
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//Inchworm/bin/fastaToKmerCoverageStats --reads left.fa --kmers jellyfish.K25.min2.kmers.fa --kmer_size 25  --num_threads 2  --DS  > left.fa.K25.stats
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//Inchworm/bin/fastaToKmerCoverageStats --reads right.fa --kmers jellyfish.K25.min2.kmers.fa --kmer_size 25  --num_threads 2  --DS  > right.fa.K25.stats
# -reading Kmer occurrences...
# -reading Kmer occurrences...
#
#  done parsing 1006423 Kmers, 1006423 added, taking 1 seconds.
#
#  done parsing 1006423 Kmers, 1006423 added, taking 1 seconds.
# STATS_GENERATION_TIME: 2 seconds.
# STATS_GENERATION_TIME: 2 seconds.
# CMD finished (4 seconds)
# CMD finished (4 seconds)
# CMD: touch left.fa.K25.stats.ok
# CMD finished (0 seconds)
# CMD: touch right.fa.K25.stats.ok
# CMD finished (0 seconds)
# -sorting each stats file by read name.
# CMD: /usr/bin/sort --parallel=2 -k5,5 -T . -S 1G left.fa.K25.stats > left.fa.K25.stats.sort
# CMD: /usr/bin/sort --parallel=2 -k5,5 -T . -S 1G right.fa.K25.stats > right.fa.K25.stats.sort
# CMD finished (0 seconds)
# CMD finished (0 seconds)
# CMD: touch left.fa.K25.stats.sort.ok
# CMD finished (0 seconds)
# CMD: touch right.fa.K25.stats.sort.ok
# CMD finished (0 seconds)
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//util/support_scripts//nbkc_merge_left_right_stats.pl --left left.fa.K25.stats.sort --right right.fa.K25.stats.sort --sorted > pairs.K25.stats
# -opening left.fa.K25.stats.sort
# -opening right.fa.K25.stats.sort
# -done opening files.
# CMD finished (0 seconds)
# CMD: touch pairs.K25.stats.ok
# CMD finished (0 seconds)
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/..//util/support_scripts//nbkc_normalize.pl pairs.K25.stats 50 10000 > pairs.K25.stats.C50.pctSD10000.accs
# 76630 / 150000 = 51.09% reads selected during normalization.
# 0 / 150000 = 0.00% reads discarded as likely aberrant based on coverage profiles.
# 0 / 150000 = 0.00% reads missing kmer coverage (N chars included?).
# CMD finished (0 seconds)
# CMD: touch pairs.K25.stats.C50.pctSD10000.accs.ok
# CMD finished (0 seconds)
# CMD: touch /workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_1.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq.ok
# CMD finished (0 seconds)
# CMD: touch /workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_2.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq.ok
# CMD finished (0 seconds)
# CMD: ln -sf /workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_1.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq left.norm.fq
# CMD finished (0 seconds)
# CMD: ln -sf /workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_2.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq right.norm.fq
# CMD finished (0 seconds)
# -removing tmp dir /workspace/transreco/trinity_out_dir/insilico_read_normalization/tmp_normalized_reads
#
#
# Normalization complete. See outputs:
# 	/workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_1.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq
# 	/workspace/transreco/trinity_out_dir/insilico_read_normalization/sA_rep1_2.fastq.gz_ext_all_reads.normalized_K25_C50_pctSD10000.fq
# Wednesday, November 14, 2018: 15:51:32	CMD: touch /workspace/transreco/trinity_out_dir/insilico_read_normalization/normalization.ok
# Converting input files. (in parallel)Wednesday, November 14, 2018: 15:51:32	CMD: cat /workspace/transreco/trinity_out_dir/insilico_read_normalization/left.norm.fq | seqtk-trinity seq -A - >> left.fa
# Wednesday, November 14, 2018: 15:51:32	CMD: cat /workspace/transreco/trinity_out_dir/insilico_read_normalization/right.norm.fq | seqtk-trinity seq -A - >> right.fa
# Wednesday, November 14, 2018: 15:51:32	CMD: touch left.fa.ok
# Wednesday, November 14, 2018: 15:51:32	CMD: touch right.fa.ok
# Wednesday, November 14, 2018: 15:51:32	CMD: touch left.fa.ok right.fa.ok
# Wednesday, November 14, 2018: 15:51:32	CMD: cat left.fa right.fa > /workspace/transreco/trinity_out_dir/both.fa
# Wednesday, November 14, 2018: 15:51:32	CMD: touch /workspace/transreco/trinity_out_dir/both.fa.ok
# -------------------------------------------
# ----------- Jellyfish  --------------------
# -- (building a k-mer catalog from reads) --
# -------------------------------------------
#
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/trinity-plugins/jellyfish/bin/jellyfish count -t 2 -m 25 -s 100000000  --canonical  /workspace/transreco/trinity_out_dir/both.fa
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/trinity-plugins/jellyfish/bin/jellyfish dump -L 1 mer_counts.jf > jellyfish.kmers.fa
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/trinity-plugins/jellyfish/bin/jellyfish histo -t 2 -o jellyfish.kmers.fa.histo mer_counts.jf
# ----------------------------------------------
# --------------- Inchworm ---------------------
# -- (Linear contig construction from k-mers) --
# ----------------------------------------------
#
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Inchworm/bin//inchworm --kmers jellyfish.kmers.fa --run_inchworm -K 25 -L 25 --monitor 1   --DS  --num_threads 2  --PARALLEL_IWORM  > /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa.tmp
# * Running CMD: mv /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa.tmp /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa
# Wednesday, November 14, 2018: 15:51:43	CMD: touch /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa.finished
# --------------------------------------------------------
# -------------------- Chrysalis -------------------------
# -- (Contig Clustering & de Bruijn Graph Construction) --
# --------------------------------------------------------
#
# inchworm_target: /workspace/transreco/trinity_out_dir/both.fa
# bowite_reads_fa: /workspace/transreco/trinity_out_dir/both.fa
# chrysalis_reads_fa: /workspace/transreco/trinity_out_dir/both.fa
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/filter_iworm_by_min_length_or_cov.pl /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa 100 10 > /workspace/transreco/trinity_out_dir/chrysalis/inchworm.K25.L25.DS.fa.min100
# * Running CMD: bowtie2-build --threads 2 -o 3 /workspace/transreco/trinity_out_dir/chrysalis/inchworm.K25.L25.DS.fa.min100 /workspace/transreco/trinity_out_dir/chrysalis/inchworm.K25.L25.DS.fa.min100 1>/dev/null
# * Running CMD: bash -c " set -o pipefail;bowtie2 --local -k 2 --threads 2 -f --score-min G,46,0 -x /workspace/transreco/trinity_out_dir/chrysalis/inchworm.K25.L25.DS.fa.min100 /workspace/transreco/trinity_out_dir/both.fa  | samtools view -@ 2 -F4 -Sb - | samtools sort -m 268435456 -@ 2 -no - - > /workspace/transreco/trinity_out_dir/chrysalis/iworm.bowtie.nameSorted.bam"
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/scaffold_iworm_contigs.pl /workspace/transreco/trinity_out_dir/chrysalis/iworm.bowtie.nameSorted.bam /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa > /workspace/transreco/trinity_out_dir/chrysalis/iworm_scaffolds.txt
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Chrysalis/GraphFromFasta -i /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa -r /workspace/transreco/trinity_out_dir/both.fa -min_contig_length 200 -min_glue 2 -glue_factor 0.05 -min_iso_ratio 0.05 -t 2 -k 24 -kk 48  -scaffolding /workspace/transreco/trinity_out_dir/chrysalis/iworm_scaffolds.txt  > /workspace/transreco/trinity_out_dir/chrysalis/iworm_cluster_welds_graph.txt
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Chrysalis/BubbleUpClustering -i /workspace/transreco/trinity_out_dir/inchworm.K25.L25.DS.fa  -weld_graph /workspace/transreco/trinity_out_dir/chrysalis/iworm_cluster_welds_graph.txt -min_contig_length 200  > /workspace/transreco/trinity_out_dir/chrysalis/GraphFromIwormFasta.out
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Chrysalis/CreateIwormFastaBundle -i /workspace/transreco/trinity_out_dir/chrysalis/GraphFromIwormFasta.out -o /workspace/transreco/trinity_out_dir/chrysalis/bundled_iworm_contigs.fasta -min 200
# * Running CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Chrysalis/ReadsToTranscripts -i /workspace/transreco/trinity_out_dir/both.fa -f /workspace/transreco/trinity_out_dir/chrysalis/bundled_iworm_contigs.fasta -o /workspace/transreco/trinity_out_dir/chrysalis/readsToComponents.out -t 2 -max_mem_reads 50000000
# * Running CMD: /usr/bin/sort --parallel=2 -T . -S 1G -k 1,1n /workspace/transreco/trinity_out_dir/chrysalis/readsToComponents.out > /workspace/transreco/trinity_out_dir/chrysalis/readsToComponents.out.sort
# Wednesday, November 14, 2018: 15:52:07	CMD: mkdir -p /workspace/transreco/trinity_out_dir/read_partitions/Fb_0/CBin_0
# Wednesday, November 14, 2018: 15:52:07	CMD: mkdir -p /workspace/transreco/trinity_out_dir/read_partitions/Fb_0/CBin_1
# Wednesday, November 14, 2018: 15:52:07	CMD: touch /workspace/transreco/trinity_out_dir/partitioned_reads.files.list.ok
# Wednesday, November 14, 2018: 15:52:07	CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/write_partitioned_trinity_cmds.pl --reads_list_file /workspace/transreco/trinity_out_dir/partitioned_reads.files.list --CPU 1 --max_memory 1G  --run_as_paired  --seqType fa --trinity_complete --full_cleanup  > recursive_trinity.cmds
# Wednesday, November 14, 2018: 15:52:07	CMD: touch recursive_trinity.cmds.ok
# Wednesday, November 14, 2018: 15:52:07	CMD: touch recursive_trinity.cmds.ok
#
#
# --------------------------------------------------------------------------------
# ------------ Trinity Phase 2: Assembling Clusters of Reads ---------------------
# --------------------------------------------------------------------------------
#
# Wednesday, November 14, 2018: 15:52:07	CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/trinity-plugins/BIN/ParaFly -c recursive_trinity.cmds -CPU 2 -v -shuffle
# Number of Commands: 168
# succeeded(168)   100% completed.
#
# All commands completed successfully. :-)
#
#
#
# ** Harvesting all assembled transcripts into a single multi-fasta file...
#
# Wednesday, November 14, 2018: 15:54:59	CMD: find /workspace/transreco/trinity_out_dir/read_partitions/ -name '*inity.fasta'  | /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/partitioned_trinity_aggregator.pl TRINITY_DN > /workspace/transreco/trinity_out_dir/Trinity.fasta.tmp
# -relocating /workspace/transreco/trinity_out_dir/Trinity.fasta.tmp to /workspace/transreco/trinity_out_dir/Trinity.fasta
# Wednesday, November 14, 2018: 15:54:59	CMD: mv /workspace/transreco/trinity_out_dir/Trinity.fasta.tmp /workspace/transreco/trinity_out_dir/Trinity.fasta
#
#
# ###################################################################
# Trinity assemblies are written to /workspace/transreco/trinity_out_dir/Trinity.fasta
# ###################################################################
#
#
# Wednesday, November 14, 2018: 15:54:59	CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/get_Trinity_gene_to_trans_map.pl /workspace/transreco/trinity_out_dir/Trinity.fasta > /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map
#
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  lhtr
# total 36M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 15:54 trinity_out_dir
#
# ```

# %% [markdown]
# **Trinity stats**
# ```
# [nathalia@aws] $  $TRINITY_HOME/util/TrinityStats.pl trinity_out_dir/Trinity.fasta
#
#
# ################################
# ## Counts of transcripts, etc.
# ################################
# Total trinity 'genes':	189
# Total trinity transcripts:	309
# Percent GC: 48.07
#
# ########################################
# Stats based on ALL transcript contigs:
# ########################################
#
# 	Contig N10: 6202
# 	Contig N20: 5321
# 	Contig N30: 4245
# 	Contig N40: 3770
# 	Contig N50: 3242
#
# 	Median contig length: 1259
# 	Average contig: 1964.40
# 	Total assembled bases: 607000
#
#
# #####################################################
# ## Stats based on ONLY LONGEST ISOFORM per 'GENE':
# #####################################################
#
# 	Contig N10: 6408
# 	Contig N20: 5223
# 	Contig N30: 4407
# 	Contig N40: 3880
# 	Contig N50: 2774
#
# 	Median contig length: 923
# 	Average contig: 1597.84
# 	Total assembled bases: 301992
#
# ```

# %% [markdown]
# ## Transcript-to-genome alignment

# %% [markdown]
# ```
# [nathalia@aws] $  gmap_build -D . -T . -d minigenome.fa.gmap -k 13 minigenome.fa
# Note: the -T flag is no longer necessary, since gmap_build now builds directly in the destination directory
# Sorting chromosomes in chrom order.  To turn off or sort other ways, use the -s flag.
# Creating files in directory ./minigenome.fa.gmap
# Running "/usr/lib/gmap/fa_coords"     -o "./minigenome.fa.gmap.coords" -f "./minigenome.fa.gmap.sources"
# Opening file minigenome.fa
#   Processed short contigs (<1000000 nt): .
# ============================================================
# Contig mapping information has been written to file ./minigenome.fa.gmap.coords.
# You should look at this file, and edit it if necessary
# If everything is okay, you should proceed by running
#     make gmapdb
# ============================================================
# Running "/usr/lib/gmap/gmap_process"  -c "./minigenome.fa.gmap.coords" -f "./minigenome.fa.gmap.sources" | "/usr/lib/gmap/gmapindex"  -d minigenome.fa.gmap -D "./minigenome.fa.gmap" -A
# Reading coordinates from file ./minigenome.fa.gmap.coords
# Logging contig minigenome at minigenome:1..781778 in genome minigenome.fa.gmap
#  => primary (linear) chromosome
# Total genomic length = 781778 bp
# Have a total of 1 chromosomes
# Writing chromosome file ./minigenome.fa.gmap/minigenome.fa.gmap.chromosome
# Chromosome minigenome has universal coordinates 1..781778
# Writing chromosome IIT file ./minigenome.fa.gmap/minigenome.fa.gmap.chromosome.iit
# Writing IIT file header information...coordinates require 4 bytes each...done
# Processing null division/chromosome...sorting...writing...done (1 intervals)
# Writing IIT file footer information...done
# Writing IIT file header information...coordinates require 4 bytes each...done
# Processing null division/chromosome...sorting...writing...done (1 intervals)
# Writing IIT file footer information...done
# No alternate scaffolds observed
# Running "/usr/lib/gmap/gmap_process"  -c "./minigenome.fa.gmap.coords" -f "./minigenome.fa.gmap.sources" | "/usr/lib/gmap/gmapindex"  -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -G
# Genome length is 781778 nt
# Trying to allocate 73293*4 bytes of memory...succeeded.  Building genome in memory.
# Reading coordinates from file ./minigenome.fa.gmap.coords
# Writing contig minigenome to universal coordinates 1..781778
# A total of 0 non-ACGTNX characters were seen in the genome.
# Running cat "./minigenome.fa.gmap/minigenome.fa.gmap.genomecomp" | "/usr/lib/gmap/gmapindex" -d minigenome.fa.gmap -U > "./minigenome.fa.gmap/minigenome.fa.gmap.genomebits128"
# Running cat "./minigenome.fa.gmap/minigenome.fa.gmap.genomecomp" | "/usr/lib/gmap/gmapindex" -k 13 -q 3  -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -N
# Counting positions in genome minigenome.fa.gmap (13 bp every 3 bp), position 0
# Number of offsets: 237366 => pages file not required
# Running "/usr/lib/gmap/gmapindex" -k 13 -q 3  -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -O  "./minigenome.fa.gmap/minigenome.fa.gmap.genomecomp"
# Offset compression types: bitpack64
# Allocating 1048576*1 bytes for packsizes
# Allocating 1048576*8 bytes for bitpacks
# Indexing offsets of oligomers in genome minigenome.fa.gmap (13 bp every 3 bp), position 0
# Writing 67108865 offsets compressed via bitpack64...done
# Running "/usr/lib/gmap/gmapindex" -k 13 -q 3  -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -P "./minigenome.fa.gmap/minigenome.fa.gmap.genomecomp"
# Looking for index files in directory ./minigenome.fa.gmap
#   Pointers file is minigenome.fa.gmap.ref133offsets64meta
#   Offsets file is minigenome.fa.gmap.ref133offsets64strm
#   Positions file is minigenome.fa.gmap.ref133positions
# Expanding offsetsstrm into counters...done
# Allocating 3103296 bytes for counterstrm
# Trying to allocate 237366*4 bytes of memory for positions...succeeded.  Building positions in memory.
# Indexing positions of oligomers in genome minigenome.fa.gmap (13 bp every 3 bp), position 0
# Writing 237366 genomic positions to file ./minigenome.fa.gmap/minigenome.fa.gmap.ref133positions ...
# done
# Running "/usr/lib/gmap/gmapindex" -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -S
# Genome length is 781778
# Building suffix array
# SACA_K called with n = 781779, K = 5, level 0
# SACA_K called with n = 200750, K = 0, level 1
# SACA_K called with n = 63708, K = 0, level 2
# SACA_K called with n = 20596, K = 0, level 3
# SACA_K called with n = 6738, K = 0, level 4
# SACA_K called with n = 2155, K = 0, level 5
# For indexsize 12, occupied 664233/16777216
# Optimal indexsize = 12
# Running "/usr/lib/gmap/gmapindex" -d minigenome.fa.gmap -F "./minigenome.fa.gmap" -D "./minigenome.fa.gmap" -L
# Building LCP array
# Writing temporary file for rank...done
# Writing temporary file for permuted sarray...done
# Found 53776 exceptions
# Byte-coding: 728003 values < 255, 53776 exceptions >= 255 (6.9%)
# Building DC array
# Building child array
# Byte-coding: 779508 values < 255, 2271 exceptions >= 255 (0.3%)
# Writing file ./minigenome.fa.gmap/minigenome.fa.gmap.salcpchilddcdone
#
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  lhtr
# total 36M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 15:54 trinity_out_dir
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
#
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  gmap -D . -d minigenome.fa.gmap trinity_out_dir/Trinity.fasta \
# >       -f samse -n 0 -x 50 -t 2 -B 5 \
# >       | samtools view -Sb | samtools sort -o Trinity.gmap.bam
# Note: gmap.avx512 does not exist.  For faster speed, may want to compile package on an AVX512 machine
# Note: gmap.avx2 does not exist.  For faster speed, may want to compile package on an AVX2 machine
# GMAP version 2017-11-15 called with args: gmap.sse42 -D . -d minigenome.fa.gmap trinity_out_dir/Trinity.fasta -f samse -n 0 -x 50 -t 2 -B 5
# Note: Batch mode 5 is now the same as batch mode 4.
# Expansion of offsets is now controlled separately by --expand-offsets (default=1).
# Checking compiler assumptions for SSE2: 6B8B4567 327B23C6 xor=59F066A1
# Checking compiler assumptions for SSE4.1: -103 -58 max=198 => compiler zero extends
# Checking compiler options for SSE4.2: 6B8B4567 __builtin_clz=1 __builtin_ctz=0 _mm_popcnt_u32=17 __builtin_popcount=17
# Finished checking compiler assumptions
# Allocating memory for compressed genome (oligos)...Attached new memory for ./minigenome.fa.gmap/minigenome.fa.gmap.genomecomp...done (293,172 bytes, 0.00 sec)
# Allocating memory for compressed genome (bits)...Attached new memory for ./minigenome.fa.gmap/minigenome.fa.gmap.genomebits128...done (293,184 bytes, 0.00 sec)
# Looking for index files in directory ./minigenome.fa.gmap
#   Pointers file is minigenome.fa.gmap.ref133offsets64meta
#   Offsets file is minigenome.fa.gmap.ref133offsets64strm
#   Positions file is minigenome.fa.gmap.ref133positions
# Offsets compression type: bitpack64
# Allocating memory for ref offset pointers, kmer 13, interval 3...Attached new memory for ./minigenome.fa.gmap/minigenome.fa.gmap.ref133offsets64meta...done (8,388,624 bytes, 0.00 sec)
# Allocating memory for ref offsets, kmer 13, interval 3...Attached new memory for ./minigenome.fa.gmap/minigenome.fa.gmap.ref133offsets64strm...done (3,103,296 bytes, 0.00 sec)
# Allocating memory for ref positions, kmer 13, interval 3...Attached new memory for ./minigenome.fa.gmap/minigenome.fa.gmap.ref133positions...done (949,464 bytes, 0.00 sec)
# Starting alignment
# No paths found for TRINITY_DN33_c0_g2_i1
# Processed 309 queries in 2.62 seconds (117.94 queries/sec)
# Removed existing memory for shmid 131076
# Removed existing memory for shmid 98307
# Removed existing memory for shmid 65538
# Removed existing memory for shmid 0
# Removed existing memory for shmid 32769
#
# [nathalia@aws] $  samtools index Trinity.gmap.bam
#
# [nathalia@aws] $  lhtr
# total 36M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 15:54 trinity_out_dir
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
# -rw-rw-r-- 1 ubuntu ubuntu 134K Nov 14 15:58 Trinity.gmap.bam
# -rw-rw-r-- 1 ubuntu ubuntu  472 Nov 14 15:58 Trinity.gmap.bam.bai
#
# ```

# %% [markdown]
# Load into IGV
#
# http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/Trinity.gmap.bam

# %% [markdown]
# ![gmap](gmap.png)

# %% [markdown]
# ## Estimating abundance
#
# https://github.com/trinityrnaseq/trinityrnaseq/wiki/Trinity-Transcript-Quantification#estimating-transcript-abundance

# %% [markdown]
# ```
# [nathalia@aws] $  mkdir abundance-kallisto
# [nathalia@aws] $  $TRINITY_HOME/util/align_and_estimate_abundance.pl  --transcripts trinity_out_dir/Trinity.fasta --seqType fq --samples_file samples.txt --est_method kallisto --output_dir abundance-kallisto --trinity_mode
# Error, no kallisto index file: /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx, and --prep_reference not set.  Re-run with --prep_reference at /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/align_and_estimate_abundance.pl line 838.
# 	main::run_kallisto(HASH(0x5636714f45f8), HASH(0x5636712c49b8), HASH(0x5636713eaa20), HASH(0x5636713b8c80), HASH(0x563671579d00), HASH(0x563671579f10)) called at /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/align_and_estimate_abundance.pl line 455
# 	main::run_alignment_FREE_estimation(HASH(0x5636714f45f8), HASH(0x5636712c49b8), HASH(0x5636713eaa20), HASH(0x5636713b8c80), HASH(0x563671579d00), HASH(0x563671579f10)) called at /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/align_and_estimate_abundance.pl line 441
#
# # need to add --prep_reference
#
# [nathalia@aws] $  $TRINITY_HOME/util/align_and_estimate_abundance.pl  --transcripts trinity_out_dir/Trinity.fasta --seqType fq --samples_file samples.txt --est_method kallisto --output_dir abundance-kallisto --trinity_mode --prep_reference
# CMD: kallisto index -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx /workspace/transreco/trinity_out_dir/Trinity.fasta
#
# [build] loading fasta file /workspace/transreco/trinity_out_dir/Trinity.fasta
# [build] k-mer length: 31
# [build] counting k-mers ... done.
# [build] building target de Bruijn graph ...  done
# [build] creating equivalence classes ...  done
# [build] target de Bruijn graph has 483 contigs and contains 316749 k-mers
#
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sA_rep1 <(gunzip -c /workspace/transreco/data/sA_rep1_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sA_rep1_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,914 reads pseudoaligned
# [quant] estimated average fragment length: 218.862
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 459 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sA_rep1/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sA_rep1/abundance.tsv.genes
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sA_rep2 <(gunzip -c /workspace/transreco/data/sA_rep2_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sA_rep2_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,944 reads pseudoaligned
# [quant] estimated average fragment length: 218.873
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 443 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sA_rep2/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sA_rep2/abundance.tsv.genes
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sA_rep3 <(gunzip -c /workspace/transreco/data/sA_rep3_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sA_rep3_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,933 reads pseudoaligned
# [quant] estimated average fragment length: 217.832
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 611 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sA_rep3/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sA_rep3/abundance.tsv.genes
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sB_rep1 <(gunzip -c /workspace/transreco/data/sB_rep1_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sB_rep1_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,957 reads pseudoaligned
# [quant] estimated average fragment length: 217.786
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 692 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sB_rep1/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sB_rep1/abundance.tsv.genes
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sB_rep2 <(gunzip -c /workspace/transreco/data/sB_rep2_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sB_rep2_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,965 reads pseudoaligned
# [quant] estimated average fragment length: 218.906
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 449 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sB_rep2/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sB_rep2/abundance.tsv.genes
# CMD: kallisto quant -i /workspace/transreco/trinity_out_dir/Trinity.fasta.kallisto_idx  -o sB_rep3 <(gunzip -c /workspace/transreco/data/sB_rep3_1.fastq.gz) <(gunzip -c /workspace/transreco/data/sB_rep3_2.fastq.gz)
#
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 309
# [index] number of k-mers: 316,749
# [index] number of equivalence classes: 472
# [quant] running in paired-end mode
# [quant] will process pair 1: /dev/fd/63
#                              /dev/fd/62
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,000 reads, 24,935 reads pseudoaligned
# [quant] estimated average fragment length: 216.619
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 834 rounds
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/kallisto_trans_to_gene_results.pl sB_rep3/abundance.tsv /workspace/transreco/trinity_out_dir/Trinity.fasta.gene_trans_map > sB_rep3/abundance.tsv.genes
#
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  lhtr
# total 36M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
# -rw-rw-r-- 1 ubuntu ubuntu 134K Nov 14 15:58 Trinity.gmap.bam
# -rw-rw-r-- 1 ubuntu ubuntu  472 Nov 14 15:58 Trinity.gmap.bam.bai
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:09 abundance-kallisto
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 16:11 trinity_out_dir
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep3
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep3
#
# ```

# %% [markdown]
# ## Build transcript and gene expression matrices

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/util/abundance_estimates_to_matrix.pl --est_method kallisto --gene_trans_map trinity_out_dir/Trinity.fasta.gene_trans_map --out_prefix kallisto --name_sample_by_basedir sA_rep1/abundance.tsv sA_rep2/abundance.tsv sA_rep3/abundance.tsv sB_rep1/abundance.tsv sB_rep2/abundance.tsv sB_rep3/abundance.tsv
# -reading file: sA_rep1/abundance.tsv
# -reading file: sA_rep2/abundance.tsv
# -reading file: sA_rep3/abundance.tsv
# -reading file: sB_rep1/abundance.tsv
# -reading file: sB_rep2/abundance.tsv
# -reading file: sB_rep3/abundance.tsv
#
#
# * Outputting combined matrix.
#
# /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/run_TMM_scale_matrix.pl --matrix kallisto.isoform.TPM.not_cross_norm > kallisto.isoform.TMM.EXPR.matrixCMD: R --vanilla -q < __tmp_runTMM.R 1>&2
# > library(edgeR)
# Loading required package: limma
# >
# > rnaseqMatrix = read.table("kallisto.isoform.TPM.not_cross_norm", header=T, row.names=1, com='', check.names=F)
# > rnaseqMatrix = as.matrix(rnaseqMatrix)
# > rnaseqMatrix = round(rnaseqMatrix)
# > exp_study = DGEList(counts=rnaseqMatrix, group=factor(colnames(rnaseqMatrix)))
# > exp_study = calcNormFactors(exp_study)
# > exp_study$samples$eff.lib.size = exp_study$samples$lib.size * exp_study$samples$norm.factors
# > write.table(exp_study$samples, file="kallisto.isoform.TPM.not_cross_norm.TMM_info.txt", quote=F, sep="\t", row.names=F)
# >
# /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/util/support_scripts/run_TMM_scale_matrix.pl --matrix kallisto.gene.TPM.not_cross_norm > kallisto.gene.TMM.EXPR.matrixCMD: R --vanilla -q < __tmp_runTMM.R 1>&2
# > library(edgeR)
# Loading required package: limma
# >
# > rnaseqMatrix = read.table("kallisto.gene.TPM.not_cross_norm", header=T, row.names=1, com='', check.names=F)
# > rnaseqMatrix = as.matrix(rnaseqMatrix)
# > rnaseqMatrix = round(rnaseqMatrix)
# > exp_study = DGEList(counts=rnaseqMatrix, group=factor(colnames(rnaseqMatrix)))
# > exp_study = calcNormFactors(exp_study)
# > exp_study$samples$eff.lib.size = exp_study$samples$lib.size * exp_study$samples$norm.factors
# > write.table(exp_study$samples, file="kallisto.gene.TPM.not_cross_norm.TMM_info.txt", quote=F, sep="\t", row.names=F)
# >
#
#
# [nathalia@aws] $  lhtr
# total 37M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
# -rw-rw-r-- 1 ubuntu ubuntu 134K Nov 14 15:58 Trinity.gmap.bam
# -rw-rw-r-- 1 ubuntu ubuntu  472 Nov 14 15:58 Trinity.gmap.bam.bai
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:09 abundance-kallisto
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 16:11 trinity_out_dir
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep3
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep3
# -rw-rw-r-- 1 ubuntu ubuntu  17K Nov 14 16:22 kallisto.isoform.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  20K Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  11K Nov 14 16:22 kallisto.gene.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 16:22 kallisto.gene.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  335 Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  22K Nov 14 16:22 kallisto.isoform.TMM.EXPR.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  526 Nov 14 16:22 __tmp_runTMM.R
# -rw-rw-r-- 1 ubuntu ubuntu  337 Nov 14 16:22 kallisto.gene.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 16:22 kallisto.gene.TMM.EXPR.matrix
#
# ```

# %% [markdown]
# ## Counting number of expressed transcripts

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/util/misc/count_matrix_features_given_MIN_TPM_threshold.pl kallisto.gene.TPM.not_cross_norm | tee genes_matrix.TPM.not_cross_norm.counts_by_min_TPM
# neg_min_tpm	num_features
# -102417	1
# -98625	2
# -79903	3
# -70405	4
# -64163	5
# -46860	6
# -44959	7
# -41042	8
# -39478	9
# -39192	10
# -35702	11
# -31449	12
# -30667	13
# -29997	14
# -29834	15
# -28664	16
# -20570	17
# -19929	18
# -19243	19
# -19039	20
# -19026	21
# -16731	22
# -16150	23
# -14600	24
# -14555	25
# -14219	26
# -14082	27
# -13899	28
# -13578	29
# -13458	30
# -13401	31
# -13362	32
# -13322	33
# -12434	34
# -11835	35
# -11488	36
# -11332	37
# -11271	38
# -11081	39
# -10841	40
# -10780	41
# -10185	42
# -9573	43
# -8900	44
# -8494	45
# -8358	46
# -8246	47
# -8128	48
# -7864	49
# -7856	50
# -7723	51
# -7647	52
# -7323	53
# -6707	54
# -6595	55
# -6506	56
# -6465	57
# -6266	58
# -6013	59
# -5981	60
# -5553	61
# -5491	62
# -5344	63
# -5330	64
# -5314	65
# -4741	66
# -4593	67
# -4282	68
# -4278	69
# -4117	70
# -4096	71
# -3998	72
# -3881	73
# -3875	74
# -3804	75
# -3740	76
# -3666	77
# -3443	78
# -3309	79
# -3108	80
# -3076	81
# -3036	82
# -3027	83
# -3015	84
# -2868	85
# -2862	86
# -2824	87
# -2818	88
# -2749	89
# -2742	90
# -2699	91
# -2694	92
# -2654	93
# -2617	94
# -2552	95
# -2387	96
# -2370	97
# -2367	98
# -2355	99
# -2345	100
# -2325	101
# -2285	102
# -2268	103
# -2215	104
# -2170	105
# -2088	106
# -2065	107
# -2056	108
# -2015	109
# -1988	110
# -1986	111
# -1963	112
# -1901	113
# -1879	114
# -1878	115
# -1837	116
# -1803	117
# -1801	119
# -1796	120
# -1750	121
# -1732	122
# -1686	123
# -1680	124
# -1665	125
# -1638	126
# -1631	127
# -1617	128
# -1608	129
# -1593	130
# -1556	131
# -1498	132
# -1485	133
# -1459	134
# -1413	135
# -1398	136
# -1395	137
# -1394	138
# -1392	140
# -1390	141
# -1369	142
# -1342	143
# -1318	144
# -1287	145
# -1220	146
# -1150	147
# -1144	148
# -1143	149
# -1132	150
# -1109	151
# -1106	152
# -1090	153
# -1026	154
# -1017	155
# -989	156
# -960	157
# -954	158
# -945	159
# -940	160
# -919	161
# -917	162
# -908	163
# -904	164
# -862	165
# -845	166
# -830	167
# -793	168
# -783	169
# -759	170
# -750	171
# -745	172
# -736	173
# -734	174
# -719	175
# -713	176
# -682	177
# -681	178
# -657	179
# -636	180
# -623	181
# -601	182
# -591	183
# -586	184
# -560	185
# -534	186
# -503	187
# -492	188
# 0	189
# [nathalia@aws] $  lhtr
# total 37M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
# -rw-rw-r-- 1 ubuntu ubuntu 134K Nov 14 15:58 Trinity.gmap.bam
# -rw-rw-r-- 1 ubuntu ubuntu  472 Nov 14 15:58 Trinity.gmap.bam.bai
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:09 abundance-kallisto
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 16:11 trinity_out_dir
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep3
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep3
# -rw-rw-r-- 1 ubuntu ubuntu  17K Nov 14 16:22 kallisto.isoform.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  20K Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  11K Nov 14 16:22 kallisto.gene.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 16:22 kallisto.gene.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  335 Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  22K Nov 14 16:22 kallisto.isoform.TMM.EXPR.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  526 Nov 14 16:22 __tmp_runTMM.R
# -rw-rw-r-- 1 ubuntu ubuntu  337 Nov 14 16:22 kallisto.gene.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 16:22 kallisto.gene.TMM.EXPR.matrix
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 16:25 genes_matrix.TPM.not_cross_norm.counts_by_min_TPM
#
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/util/misc/count_matrix_features_given_MIN_TPM_threshold.pl kallisto.isoform.TPM.not_cross_norm | tee isoform_matrix.TPM.not_cross_norm.counts_by_min_TPM
# neg_min_tpm	num_features
# -102417	1
# -98625	2
# -61862	3
# -56379	4
# -49690	5
# -47736	6
# -41042	7
# -36709	8
# -36363	9
# -35452	10
# -35010	11
# -31833	12
# -31449	13
# -31196	14
# -28051	15
# -25339	16
# -23815	17
# -22599	18
# -22503	19
# -20570	20
# -19929	21
# -19802	22
# -19026	23
# -16892	24
# -16667	25
# -16150	26
# -15822	27
# -15131	28
# -14986	29
# -14682	30
# -14062	31
# -13578	32
# -13322	33
# -13034	34
# -12861	35
# -12667	36
# -12555	37
# -12322	38
# -12258	39
# -11919	41
# -11488	42
# -11192	43
# -11081	44
# -10979	45
# -10841	46
# -10822	47
# -10185	48
# -9888	49
# -9663	50
# -9573	51
# -9504	52
# -9437	53
# -9414	54
# -9260	55
# -9226	56
# -9141	57
# -9076	58
# -8940	59
# -8900	60
# -8436	61
# -8358	62
# -8266	63
# -8190	64
# -8152	65
# -7915	66
# -7864	67
# -7856	68
# -7608	69
# -7323	70
# -7236	71
# -7110	72
# -6905	73
# -6558	74
# -6506	75
# -6465	76
# -6340	77
# -6266	78
# -6166	79
# -6117	80
# -6101	81
# -5999	82
# -5981	83
# -5928	84
# -5749	85
# -5553	86
# -5491	87
# -5431	88
# -5344	89
# -5314	90
# -5197	91
# -4947	92
# -4573	93
# -4439	94
# -4385	95
# -4381	96
# -4361	97
# -4285	98
# -4278	99
# -4243	100
# -4195	101
# -4091	102
# -3993	103
# -3885	104
# -3806	105
# -3751	106
# -3740	107
# -3646	108
# -3496	109
# -3485	110
# -3449	111
# -3367	112
# -3355	113
# -3316	114
# -3309	115
# -3278	116
# -3277	117
# -3253	118
# -3235	119
# -3198	120
# -3112	121
# -3110	122
# -3109	123
# -3106	124
# -3076	125
# -3036	126
# -3027	127
# -3015	128
# -3010	129
# -2950	130
# -2868	131
# -2862	132
# -2837	133
# -2824	134
# -2818	135
# -2780	136
# -2749	137
# -2742	138
# -2699	139
# -2696	140
# -2694	141
# -2654	142
# -2648	143
# -2639	144
# -2617	145
# -2514	146
# -2484	147
# -2453	148
# -2444	149
# -2387	150
# -2370	151
# -2355	152
# -2347	153
# -2345	154
# -2340	155
# -2325	156
# -2310	157
# -2286	158
# -2268	159
# -2226	160
# -2215	161
# -2170	162
# -2142	163
# -2123	164
# -2088	165
# -2065	167
# -2064	168
# -2056	169
# -2015	170
# -1986	171
# -1969	172
# -1965	173
# -1963	175
# -1957	176
# -1901	177
# -1879	178
# -1878	179
# -1869	180
# -1837	181
# -1830	182
# -1816	183
# -1803	184
# -1802	185
# -1801	187
# -1796	188
# -1760	189
# -1750	190
# -1732	192
# -1707	193
# -1694	194
# -1686	195
# -1684	196
# -1680	197
# -1673	198
# -1665	199
# -1638	200
# -1631	201
# -1617	202
# -1616	203
# -1608	204
# -1593	205
# -1588	206
# -1556	207
# -1550	208
# -1498	209
# -1485	210
# -1441	211
# -1420	212
# -1413	213
# -1404	214
# -1401	215
# -1398	216
# -1395	217
# -1394	218
# -1392	220
# -1390	221
# -1389	222
# -1369	223
# -1352	224
# -1350	225
# -1342	226
# -1318	227
# -1273	228
# -1266	229
# -1243	230
# -1220	231
# -1192	232
# -1186	233
# -1173	234
# -1158	235
# -1150	236
# -1144	237
# -1143	238
# -1132	239
# -1117	240
# -1109	241
# -1107	242
# -1106	243
# -1104	244
# -1096	245
# -1090	246
# -1036	247
# -1017	248
# -1011	249
# -989	250
# -960	251
# -954	252
# -945	253
# -940	254
# -938	255
# -921	256
# -919	257
# -917	258
# -908	259
# -904	260
# -862	261
# -845	262
# -830	263
# -801	264
# -793	265
# -783	266
# -759	267
# -750	268
# -749	269
# -745	270
# -736	271
# -734	272
# -713	273
# -682	274
# -681	275
# -673	276
# -657	277
# -648	278
# -644	279
# -636	280
# -630	281
# -623	282
# -622	283
# -608	284
# -604	285
# -601	286
# -591	287
# -586	288
# -584	289
# -578	290
# -560	291
# -555	292
# -534	293
# -515	294
# -512	295
# -504	296
# -503	297
# -492	299
# -447	300
# -441	301
# -405	302
# -349	303
# -301	304
# -288	305
# -128	306
# 0	309
# [nathalia@aws] $  lhtr
# total 37M
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 15:24 data
# -rw-r--r-- 1 ubuntu ubuntu 777K Nov 14 15:24 minigenome.fa
# -rw-r--r-- 1 ubuntu ubuntu  354 Nov 14 15:24 samples.txt
# -rw-r--r-- 1 ubuntu ubuntu 1.2M Nov 14 15:24 minigenome.gtf
# -rw-rw-r-- 1 ubuntu ubuntu   27 Nov 14 15:25 minigenome.fa.fai
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 15:33 minigenome.gtf.ss
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 15:33 minigenome.gtf.exons
# -rw-rw-r-- 1 ubuntu ubuntu 175K Nov 14 15:33 minigenome.fa.4.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  944 Nov 14 15:33 minigenome.fa.3.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 3.8K Nov 14 15:33 minigenome.fa.8.ht2
# -rw-rw-r-- 1 ubuntu ubuntu  19K Nov 14 15:33 minigenome.fa.7.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 176K Nov 14 15:33 minigenome.fa.2.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.5M Nov 14 15:33 minigenome.fa.1.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 179K Nov 14 15:33 minigenome.fa.6.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 509K Nov 14 15:33 minigenome.fa.5.ht2
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:39 sA_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:40 sB_rep1.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 4.6M Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sA_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.7K Nov 14 15:41 sA_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.6K Nov 14 15:41 sB_rep1.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.4K Nov 14 15:41 sB_rep2.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 15:41 sB_rep3.cSorted.hisat2.minigenome.fa.bam.bai
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sA_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 106K Nov 14 15:45 sA_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 105K Nov 14 15:45 sA_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 108K Nov 14 15:45 sB_rep1.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu  99K Nov 14 15:45 sB_rep2.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 103K Nov 14 15:45 sB_rep3.cSorted.hisat2.minigenome.fa.bam.stringtie.GTF
# -rw-rw-r-- 1 ubuntu ubuntu 141K Nov 14 15:45 stringtie.final.GTF
# drwxrwxr-x 3 ubuntu ubuntu 4.0K Nov 14 15:57 minigenome.fa.gmap
# -rw-rw-r-- 1 ubuntu ubuntu 134K Nov 14 15:58 Trinity.gmap.bam
# -rw-rw-r-- 1 ubuntu ubuntu  472 Nov 14 15:58 Trinity.gmap.bam.bai
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:09 abundance-kallisto
# drwxrwxr-x 5 ubuntu ubuntu 4.0K Nov 14 16:11 trinity_out_dir
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sA_rep3
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep1
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep2
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Nov 14 16:11 sB_rep3
# -rw-rw-r-- 1 ubuntu ubuntu  17K Nov 14 16:22 kallisto.isoform.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  20K Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  11K Nov 14 16:22 kallisto.gene.counts.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  13K Nov 14 16:22 kallisto.gene.TPM.not_cross_norm
# -rw-rw-r-- 1 ubuntu ubuntu  335 Nov 14 16:22 kallisto.isoform.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  22K Nov 14 16:22 kallisto.isoform.TMM.EXPR.matrix
# -rw-rw-r-- 1 ubuntu ubuntu  526 Nov 14 16:22 __tmp_runTMM.R
# -rw-rw-r-- 1 ubuntu ubuntu  337 Nov 14 16:22 kallisto.gene.TPM.not_cross_norm.TMM_info.txt
# -rw-rw-r-- 1 ubuntu ubuntu  14K Nov 14 16:22 kallisto.gene.TMM.EXPR.matrix
# -rw-rw-r-- 1 ubuntu ubuntu 1.8K Nov 14 16:25 genes_matrix.TPM.not_cross_norm.counts_by_min_TPM
# -rw-rw-r-- 1 ubuntu ubuntu 2.9K Nov 14 16:27 isoform_matrix.TPM.not_cross_norm.counts_by_min_TPM
# ```

# %% [markdown]
# ## Filtering Transcripts based on expression values

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/util/filter_low_expr_transcripts.pl --matrix kallisto.gene.TPM.not_cross_norm  --transcripts trinity_out_dir/Trinity.fasta  --gene_to_trans_map trinity_out_dir/Trinity.fasta.gene_trans_map  --highest_iso_only
#
# (...)
# #stdout is huge
# #sequences printed to stdout... ?!
# ```

# %% [markdown]
# # DE analysis

# %% [markdown]
# ### edgeR

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/Analysis/DifferentialExpression/run_DE_analysis.pl  --matrix kallisto.gene.counts.matrix --method edgeR --dispersion 0.1
# -note, no biological replicates identified, so setting min reps = 2.
# Got 6 samples, and got: 7 data fields.
# Header: sA_rep1	sA_rep2	sA_rep3	sB_rep1	sB_rep2	sB_rep3
# Next: TRINITY_DN0_c0_g1	8.85	8.45	12.28	8.51	2.89	5.83
#
# $VAR1 = {
#           'sB_rep3' => 6,
#           'sA_rep2' => 2,
#           'sA_rep3' => 3,
#           'sB_rep2' => 5,
#           'sA_rep1' => 1,
#           'sB_rep1' => 4
#         };
# $VAR1 = {
#           'sB_rep1' => [
#                          'sB_rep1'
#                        ],
#           'sA_rep1' => [
#                          'sA_rep1'
#                        ],
#           'sA_rep3' => [
#                          'sA_rep3'
#                        ],
#           'sB_rep2' => [
#                          'sB_rep2'
#                        ],
#           'sA_rep2' => [
#                          'sA_rep2'
#                        ],
#           'sB_rep3' => [
#                          'sB_rep3'
#                        ]
#         };
# Contrasts to perform are: $VAR1 = [
#           [
#             'sA_rep1',
#             'sA_rep2'
#           ],
#           [
#             'sA_rep1',
#             'sA_rep3'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep3'
#           ],
#           [
#             'sA_rep2',
#             'sA_rep3'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep3'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep3'
#           ],
#           [
#             'sB_rep1',
#             'sB_rep2'
#           ],
#           [
#             'sB_rep1',
#             'sB_rep3'
#           ],
#           [
#             'sB_rep2',
#             'sB_rep3'
#           ]
#         ];
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.sA_rep1.vs.sA_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,2)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sA_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sA_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sA_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.sA_rep1.vs.sA_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,3)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sA_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sA_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sA_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.sA_rep1.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.sA_rep1.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.sA_rep1.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.sA_rep2.vs.sA_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,3)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sA_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sA_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sA_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.sA_rep2.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.sA_rep2.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.sA_rep2.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.sA_rep3.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.sA_rep3.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.sA_rep3.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.sB_rep1.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(4,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep1", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep1", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep1", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.sB_rep1.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(4,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep1", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep1", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep1", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.sB_rep2.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(5,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep2", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep2", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep2", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
#
# ```

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/edgeR.22490.dir/kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# Out:
# <img src="http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/edgeR.22490.dir/kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results.MA_n_Volcano.pdf"/>

# %% [markdown]
# ## voom

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/Analysis/DifferentialExpression/run_DE_analysis.pl  --matrix kallisto.gene.counts.matrix --method voom --samples_file samples.txt
# Got 6 samples, and got: 7 data fields.
# Header: sA_rep1	sA_rep2	sA_rep3	sB_rep1	sB_rep2	sB_rep3
# Next: TRINITY_DN0_c0_g1	8.85	8.45	12.28	8.51	2.89	5.83
#
# $VAR1 = {
#           'sB_rep3' => 6,
#           'sB_rep2' => 5,
#           'sB_rep1' => 4,
#           'sA_rep1' => 1,
#           'sA_rep3' => 3,
#           'sA_rep2' => 2
#         };
# $VAR1 = {
#           'sA' => [
#                     'sA_rep1',
#                     'sA_rep2',
#                     'sA_rep3'
#                   ],
#           'sB' => [
#                     'sB_rep1',
#                     'sB_rep2',
#                     'sB_rep3'
#                   ]
#         };
# Contrasts to perform are: $VAR1 = [
#           [
#             'sA',
#             'sB'
#           ]
#         ];
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_vs_sB.sA.vs.sB.voom.Rscript
# > library(edgeR)
# Loading required package: limma
# > library(limma)
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,2,3,4,5,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 2,]
# > conditions = factor(c(rep("sA", 3), rep("sB", 3)))
# >
# > design = model.matrix(~conditions)
# > ## TMM normalize data
# > lib_sizes = colSums(rnaseqMatrix)
# > tmm_norm_factors = calcNormFactors(rnaseqMatrix, method='TMM')
# > x = DGEList(counts=rnaseqMatrix)
# > # voom transformation
# > y = voom(x, design, lib.size=lib_sizes*tmm_norm_factors, plot=F)
# > fit = eBayes(lmFit(y,design))
# > tTags = topTable(fit,coef=2,number=Inf)
# > # output results, including average expression val for each feature
# > c = cpm(x)
# > m = apply(c, 1, mean)
# > tTags$logFC = -1 * tTags$logFC  # make A/B instead of B/A
# > tTags2 = cbind(tTags, logCPM=log2(m[rownames(tTags)]))
# > DE_matrix = data.frame(sampleA="sA", sampleB="sB", logFC=tTags$logFC, logCPM=tTags2$logCPM, PValue=tTags$'P.Value', FDR=tTags$'adj.P.Val')
# > rownames(DE_matrix) = rownames(tTags)
# > write.table(DE_matrix, file='kallisto.gene.counts.matrix.sA_vs_sB.voom.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_vs_sB.voom.count_matrix', sep='	', quote=F, row.names=T)
# > # MA and volcano plots
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_vs_sB.voom.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(tTags2), tTags2$logCPM, tTags$logFC, tTags$'adj.P.Val')
# > dev.off()
# null device
#           1
# >
# ```

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/Analysis/DifferentialExpression/run_DE_analysis.pl  --matrix kallisto.gene.counts.matrix --method edgeR --dispersion 0.1
# -note, no biological replicates identified, so setting min reps = 2.
# Got 6 samples, and got: 7 data fields.
# Header: sA_rep1	sA_rep2	sA_rep3	sB_rep1	sB_rep2	sB_rep3
# Next: TRINITY_DN0_c0_g1	8.85	8.45	12.28	8.51	2.89	5.83
#
# $VAR1 = {
#           'sA_rep1' => 1,
#           'sB_rep3' => 6,
#           'sB_rep2' => 5,
#           'sA_rep2' => 2,
#           'sB_rep1' => 4,
#           'sA_rep3' => 3
#         };
# $VAR1 = {
#           'sA_rep2' => [
#                          'sA_rep2'
#                        ],
#           'sA_rep3' => [
#                          'sA_rep3'
#                        ],
#           'sB_rep1' => [
#                          'sB_rep1'
#                        ],
#           'sA_rep1' => [
#                          'sA_rep1'
#                        ],
#           'sB_rep3' => [
#                          'sB_rep3'
#                        ],
#           'sB_rep2' => [
#                          'sB_rep2'
#                        ]
#         };
# Contrasts to perform are: $VAR1 = [
#           [
#             'sA_rep1',
#             'sA_rep2'
#           ],
#           [
#             'sA_rep1',
#             'sA_rep3'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep1',
#             'sB_rep3'
#           ],
#           [
#             'sA_rep2',
#             'sA_rep3'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep2',
#             'sB_rep3'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep1'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep2'
#           ],
#           [
#             'sA_rep3',
#             'sB_rep3'
#           ],
#           [
#             'sB_rep1',
#             'sB_rep2'
#           ],
#           [
#             'sB_rep1',
#             'sB_rep3'
#           ],
#           [
#             'sB_rep2',
#             'sB_rep3'
#           ]
#         ];
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.sA_rep1.vs.sA_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,2)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sA_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sA_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sA_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.sA_rep1.vs.sA_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,3)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sA_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sA_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sA_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sA_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.sA_rep1.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.sA_rep1.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.sA_rep1.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(1,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep1", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep1", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep1", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep1_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.sA_rep2.vs.sA_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,3)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sA_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sA_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sA_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sA_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.sA_rep2.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.sA_rep2.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.sA_rep2.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(2,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep2", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep2", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep2", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep2_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.sA_rep3.vs.sB_rep1.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,4)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep1", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep1"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep1", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep1.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.sA_rep3.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.sA_rep3.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(3,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sA_rep3", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sA_rep3", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sA_rep3", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sA_rep3_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.sB_rep1.vs.sB_rep2.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(4,5)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep1", 1), rep("sB_rep2", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep1", "sB_rep2"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep1", sampleB="sB_rep2", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep2.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.sB_rep1.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(4,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep1", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep1", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep1", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep1_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
# CMD: R --vanilla -q < kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.sB_rep2.vs.sB_rep3.EdgeR.Rscript
# > library(edgeR)
# Loading required package: limma
# >
# > data = read.table("/workspace/transreco/kallisto.gene.counts.matrix", header=T, row.names=1, com='')
# > col_ordering = c(5,6)
# > rnaseqMatrix = data[,col_ordering]
# > rnaseqMatrix = round(rnaseqMatrix)
# > rnaseqMatrix = rnaseqMatrix[rowSums(cpm(rnaseqMatrix) > 1) >= 1,]
# > conditions = factor(c(rep("sB_rep2", 1), rep("sB_rep3", 1)))
# >
# > exp_study = DGEList(counts=rnaseqMatrix, group=conditions)
# > exp_study = calcNormFactors(exp_study)
# > et = exactTest(exp_study, pair=c("sB_rep2", "sB_rep3"), dispersion=0.1)
# > tTags = topTags(et,n=NULL)
# > result_table = tTags$table
# > result_table = data.frame(sampleA="sB_rep2", sampleB="sB_rep3", result_table)
# > result_table$logFC = -1 * result_table$logFC
# > write.table(result_table, file='kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.DE_results', sep='	', quote=F, row.names=T)
# > write.table(rnaseqMatrix, file='kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.count_matrix', sep='	', quote=F, row.names=T)
# > source("/home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/R/rnaseq_plot_funcs.R")
# > pdf("kallisto.gene.counts.matrix.sB_rep2_vs_sB_rep3.edgeR.DE_results.MA_n_Volcano.pdf")
# > plot_MA_and_Volcano(rownames(result_table), result_table$logCPM, result_table$logFC, result_table$FDR)
# > dev.off()
# null device
#           1
# >
#
# ```

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/voom.22371.dir/kallisto.gene.counts.matrix.sA_vs_sB.voom.DE_results.MA_n_Volcano.pdf")
# Out:
# <img src="http://ec2-34-221-102-104.us-west-2.compute.amazonaws.com/workspace/transreco/voom.22371.dir/kallisto.gene.counts.matrix.sA_vs_sB.voom.DE_results.MA_n_Volcano.pdf"/>

# %% [markdown]
# ## Extracting and clustering differentially expressed transcripts

# %% [markdown]
# ### edgeR

# %% [markdown]
# ```
# [nathalia@aws] $  $TRINITY_HOME/Analysis/DifferentialExpression/analyze_diff_expr.pl --matrix ../kallisto.gene.TMM.EXPR.matrix -P 1e-3 -C 2
#
#
# ** Found 28 features as differentially expressed.
#
# CMD: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/PtR -m diffExpr.P1e-3_C2.matrix --log2 --heatmap --min_colSums 0 --min_rowSums 0 --gene_dist euclidean --sample_dist euclidean --sample_cor_matrix --center_rows --save
# CMD: R --vanilla -q < diffExpr.P1e-3_C2.matrix.R
# > library(cluster)
# > library(Biobase)
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rowMeans, rownames, rowSums, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# > library(qvalue)
# Error in library(qvalue) : there is no package called ‘qvalue’
# Execution halted
# Error, cmd: R --vanilla -q < diffExpr.P1e-3_C2.matrix.R died with ret 256 at /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/PtR line 1693.
# Error, Error, cmd: /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/PtR -m diffExpr.P1e-3_C2.matrix --log2 --heatmap --min_colSums 0 --min_rowSums 0 --gene_dist euclidean --sample_dist euclidean --sample_cor_matrix --center_rows --save  died with ret 6400 at /home/ubuntu/trinityrnaseq-Trinity-v2.5.1/Analysis/DifferentialExpression/analyze_diff_expr.pl line 272.
# [nathalia@aws] $  R
#
# R version 3.4.4 (2018-03-15) -- "Someone to Lean On"
# Copyright (C) 2018 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > install.packages("qvalue")
# Installing package into ‘/home/ubuntu/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Warning message:
# package ‘qvalue’ is not available (for R version 3.4.4)
# >
#
# ```

# %% [markdown]
#  no qvalue package bc of R version.... BS
